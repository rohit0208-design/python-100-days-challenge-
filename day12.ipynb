# %%
def number_oddoreven (num):
    if num %2 == 0:
        return True
    else:
        return False
number = int(input())
res = number_oddoreven(number)
print(res)
# Out:
#  7
# False

# %%
def string_lenght(a):
    count = 0
    for ch in a :
        count+1
        return a

s = input("enter the string:")
res = string_lenght(s)
print(res)
# Out:
# enter the string: asdf
# asdf

# %%
def sum(n1,n2):
    res=n1+n2
    print(res)
a= int(input())
b=int(input())
print(a+b)
# Out:
#  1
#  2
# 3

# %%
def sum(n1,n2,n3):
    res=n1+n2+n3
    print(res)
a= int(input())
b=int(input())
c=int(input())
print(a+b+c)
# Out:
#  2
#  3
#  4
# 9

# %%
def sum(n1,n2,n3,n4):
    res=n1+n2+n3+n4
    print(res)
a= int(input())
b=int(input())
c=int(input())
d=int(input())
print(a+b+c+d)
# Out:
#  2
#  3
#  4
#  2
# 11

# %%
#list properties
#list is mutable 
lst = [10,2,3,4,5.234,'hi',"hello"]
print(lst[2])
print(lst[-3])
print(lst[2:])
# Out:
# 3
# 5.234
# [3, 4, 5.234, 'hi', 'hello']

# %%
#list is mutable 
lst = [1,2,34,5,5,43,22,2,1,'hu','rgeg']
lst[2]=123
print(lst)
# Out:
# [1, 2, 123, 5, 5, 43, 22, 2, 1, 'hu', 'rgeg']

# %%
#string is immutable 
s = 'hi'
s[o] ='z'
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 #string is immutable
#       2 s = 'hi'
# ----> 3 s[o] ='z'
#       4 print(s)
#
# NameError: name 'o' is not defined

# %%
#nested list element access 
lst = [1,2,3,34,[[1,2,3],['a','b','c']],123,34]
print(lst)
print(lst[4][1])
print(lst[4][1][2])
# Out:
# [1, 2, 3, 34, [[1, 2, 3], ['a', 'b', 'c']], 123, 34]
# ['a', 'b', 'c']
# c

# %%
#reading list of elements from the user 
l = list(map(int,input().split(',')))
print(type(l),l)
# Out:
#  1,2,3,4,4
# <class 'list'> [1, 2, 3, 4, 4]

# %%
#read list of numbers and if number is even ad 0.5 and add 1 for odd numbers 
lst = list(map(int,input().split(",")))
for i in range (0,len(lst)):
    if lst [i] %2==0:
        lst[i] = lst[i]+0.5
else:
    lst[i] = lst[i]+1
    print(lst)
# Out:
#  6
# [7.5]
