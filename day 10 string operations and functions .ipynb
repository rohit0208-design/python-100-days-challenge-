# %%
s = "CODEGNAN"

# %%
print(s)
# Out:
# CODEGNAN

# %% [markdown]
# # string operations
# ## string operations
# ### string operations
# #### string operations
# . string concatenation -(+)
# . string repet - (*)

# %%
s1= "code"
s2= "gnan"
s3= s1 + " "+s2
print(s3)
# Out:
# code gnan

# %%
print(s1+s1+s1+s1)
# Out:
# codecodecodecode

# %%
print(s1*7)
# Out:
# codecodecodecodecodecodecode

# %%
s="codegnan"
print(s[0])
# Out:
# c

# %%
s="codegnan"
s = 'z' + s[1:]
print(s)
# Out:
# zodegnan

# %%
s = "codegnan"
print((s+" " )*4)
# Out:
# codegnan codegnan codegnan codegnan

# %% [markdown]
# # string functions
# . case conversions lower(),upper(),title(),swapcase(),capitalize()

# %%
s = "i am a python studenT "
print(s.lower())
print(s.upper())
print(s.title())
print(s.swapcase())
print(s.capitalize())
# Out:
# i am a python student
# I AM A PYTHON STUDENT
# I Am A Python Student
# I AM A PYTHON STUDENt
# I am a python student

# %% [markdown]
# # sub string index finding
# . find()

# %%
s = "i am a python studenT "
print(s.find("p"))
print(s.find ("t",10))
# Out:
# 7
# 15

# %%
#strip () it removes the white space 
s= "            codegnan          "
print(s.rstrip())
print(s.lstrip())
print(s.strip())
# Out:
#             codegnan
# codegnan
# codegnan

# %%
s="@@@@@@@@@@@rgnan@@@@@@@@@"
print(s.split("@"))
print(s.rsplit("@"))
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', 'rgnan', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', 'rgnan', '', '', '', '', '', '', '', '', '']

# %%
#case checking functions 
s1 = "CODE"
s2="gnan"
s3="abc123"
s4="123"
s5="Codegnan"
print(s1.isupper())
print(s2.isupper())
print(s2.islower())
print(s4.isdigit())
print(s3.isdigit())
print(s3.isalnum())
print(s3.isalpha())
print(s5.isalpha())
print(s2.isalnum())
# Out:
# True
# False
# True
# True
# False
# True
# False
# True
# True

# %%
#membership operator
'r' in 'rohit'
# Out:
# False

# %%
"""#username validation 
- minimum validation - 8 
- atleast one upper case and one lower case letter 
- special characters ('_','@')
- it contains digits 
#pass"""
# Out:
# "#username validation \n- minimum validation - 8 \n- atleast one upper case and one lower case letter \n- special characters ('_','@')\n- it contains digits \n#pass"

# %%
s = input()
validate_string = "qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM1234567890@_"
if len(s) <=8:
if s[0].isupper or s[0].islower():
    for i in range(1,len(s)):
    if s[i] not in validate_string:
        print(f" ivalid username {s[i]}")
        break
    else:
        print("invalid username ") 
else:
    print("usernme is not valid beacuse the the first charavter is not upper or lower ")
else:
# Out:
#   Cell In[6], line 4
#     if s[0].isupper or s[0].islower():
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3
