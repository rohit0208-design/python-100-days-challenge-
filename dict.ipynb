# %%
ph_book={}
def add_contact(name:str,number:int):
    if name not in ph_book:
        ph_book[name]=number
        print("contact saved")
    else:
        print("name already exists")
#update phonenumber in ph_book 
def update_number(name:str,number:int):
    if name not in ph_book:
        print("contact not exists")
    else:
        ph_book[name]=number
        print("mobile number updated")

#delete contact 
def delete_contact(name:str):
    if name in ph_book:
        ph_book.pop(name)
        print("succesfully deleted")
    else:
        print("contact not found")
#get contact 
def get_contact(name:str):
    if name in ph_book:
        ph_book.get(name,"name not found")
        print("the conntact number update is :" , number)
#print all contacts
def all_contact():
    #if contact book is empty 
    if not ph_book:
        print(" no contacts found")
        reryrn 
        for name , number in ph_book. items():
            print(f"{name} : {number}")
#main 
if __name__ == '__main__':
    print(" welcome to contact book")

#print all contact menu 
def menu():
    while True:
        print("/n---contact book meny ---")
        print("1.add contact")
        print("2.update contact")
        print("3.delete contact")
        print("4.get contact")
        print("5.all contacts")
        print("6.exists")

#choice input
choice = input("enter your choice (1-4):")
if choice=="1":
    name =input("enter name: Rohit kumar")
    number = int(input("enter number:98482345783"))
    add_contact(name,number)


elif choice=="2":
    name =input("enter name: vishnu")
    number = int(input("enter number:98342563243"))
    add_contact(name,number)


elif choice=="3":
    name =input("enter name: pandu")
    number = int(input("enter number:213456754675"))
    add_contact(name,number)



elif choice=="4":
    name =input("enter name: prabhas")
    number = int(input("enter number:32145678364")) 
    add_contact(name,number)
