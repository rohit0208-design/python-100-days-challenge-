# %%
#syntax erros
if i == 0
print(0)
# Out:
#   Cell In[5], line 2
#     if i == 0
#              ^
# SyntaxError: expected ':'

# %%
#syntax erros
if i == 0:
print(0)
# Out:
#   Cell In[7], line 3
#     print(0)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
print("hello)
print(1)
# Out:
#   Cell In[2], line 1
#     print("hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello"
# Out:
#   Cell In[3], line 1
#     print("hello"
#                  ^
# _IncompleteInputError: incomplete input

# %%
a =10
a.append(20)
print(a)
# Out:
#   Cell In[8], line 1
#     a =10
#     ^
# IndentationError: unexpected indent

# %%
a = 10 
b=0
c=a/b
print(c)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 a = 10
#       2 b=0
# ----> 3 c=a/b
#       4 print(c)
#
# ZeroDivisionError: division by zero

# %%
#index eroor
s=[1,2,3,4,5]
print(s[1])
print(s[44])
# Out:
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 s=[1,2,3,4,5]
#       3 print(s[1])
# ----> 4 print(s[44])
#
# IndexError: list index out of range

# %%
t = (1,2,3,4)
t[0] = 100
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 t = (1,2,3,4)
# ----> 2 t[0] = 100
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
s = "python"
print(s+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 s = "python"
# ----> 2 print(s+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
try :
    a=10
    b=2
    print(a/b)
except:
    print("something wrong in logic")
# Out:
# 5.0

# %%
try :
    a=10
    b=0
    print(a/b)
except:
    print("something wrong in logic")
# Out:
# something wrong in logic

# %%
try :
    a=10
    b=0
    print(a/b)
except ZeroDivisionError:
    print("zero division not possible")
except:
    print("something wrong in logic")
# Out:
# zero division not possible

# %%
try :
    a=10
    b="hi"
    print(a/b+5)
except ZeroDivisionError:
    print("zero division not possible")
except:
    print("something wrong in logic")
# Out:
# something wrong in logic

# %%
try :
    a=10
    b="hi"
    print(a/b+5)
except ZeroDivisionError:
    print("zero division not possible")
except:
    print("something wrong in logic")
# Out:
# something wrong in logic

# %%
try :
    a=10
    b="hi"
    print(a+b)
except ZeroDivisionError:
    print("zero division not possible")
except TypeError:
    print("concatenation b/w string and int is not possible")
# Out:
# concatenation b/w string and int is not possible

# %%
try :
    a=10
    b="hi"
    print(a+b)
except ZeroDivisionError:
    print("zero division not possible")
except TypeError:
    print("concatenation b/w string and int is not possible")
# Out:
# concatenation b/w string and int is not possible

# %%
try :
    a=[1,2,3,4,45]
    print(a[35])
except ZeroDivisionError:
    print("zero division not possible")
except TypeError:
    print("concatenation b/w string and int is not possible")
except Exception as e:
    print(e)
# Out:
# list index out of range
