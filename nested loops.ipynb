# %%
#nested loops 
for i in range(1,3):
    for j in range(1,4):
        print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3

# %%
#write 3 table program in functions 
def table(number):
    for i in range (1,11):
        print(f"{number} * {i}={number*i}")

num = int(input())
table(num)
# Out:
#  2
# 2 * 1=2
# 2 * 2=4
# 2 * 3=6
# 2 * 4=8
# 2 * 5=10
# 2 * 6=12
# 2 * 7=14
# 2 * 8=16
# 2 * 9=18
# 2 * 10=20

# %%
#print n stars in horizantally
n = int(input())
for i in range (1,n+1):
    print ("*", end = " " )
# Out:
#  3
# * * *

# %%
n = int(input())
print ("*" * n)
# Out:
#  5
# *****

# %%
#pattern printing 
#rectangle 
n = int(input())
for i in range (1,n+1):
    for j in range(1,n+1):
        print ("*",end = " ")
    print()
# Out:
#  6
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *
# * * * * * *

# %%
n=int(input())
for i in range (n):
    for j in range (n):
        if i>=j:
            print("*", end =  " ")
    print()
# Out:
#  5
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n = int(input())
for i in range (n):
    for j in range(n):
        if i == j:
            print("*", end = " ")
        else:
            print (" " , end = " ")
    print()
# Out:
#  5
# *
#   *
#     *
#       *
#         *

# %%
n = int(input())
for i in range(n):
    for j in range(n):
      if i>=j:
            print("*", end = " " )
    print()
# Out:
#  6
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
